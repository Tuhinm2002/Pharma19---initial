# %%
import pandas as pd
import numpy as np

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2023-01-12 20:06:58--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2023-01-12 20:06:59--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M   234KB/s    in 2m 0s
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %%
! ls
# Out:
#  data	       data.zip   padel.zip			 SarsCov1.ipynb
#  DATA.ipynb    drug_app  'QSAR CORONAVIRUS DATA.ipynb'
#  dataset.csv   padel.sh  'QSAR Drug Discovery.ipynb'

# %%
import os
os.listdir('data/')
# Out:
# ['corona_drug1.csv',
#  'corona_drug2_sars2.csv',
#  'descriptors_output.csv',
#  'descriptors_output2.csv',
#  'descriptors_output3.csv',
#  'SARS_1.csv']

# %%
selection = ['canonical_smiles','molecule_chembl_id']

# %%
try:
    
    df1 = pd.read_csv('data/corona_drug1.csv')
    df1_selected = df1[selection]
    df1_selected.to_csv('molecule1.smi',sep='\t',index=False,header=False)
except:
    pass

# %%
! cat molecule1.smi | wc -l
# Out:
# 133

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL187579 in molecule1.smi (1/133).
# Processing CHEMBL188487 in molecule1.smi (2/133).
# Processing CHEMBL185698 in molecule1.smi (3/133).
# Processing CHEMBL187717 in molecule1.smi (5/133).
# Processing CHEMBL426082 in molecule1.smi (4/133).
# Processing CHEMBL365134 in molecule1.smi (6/133).
# Processing CHEMBL187598 in molecule1.smi (7/133).
# Processing CHEMBL190743 in molecule1.smi (8/133).
# Processing CHEMBL365469 in molecule1.smi (9/133). Average speed: 2.55 s/mol.
# Processing CHEMBL188983 in molecule1.smi (10/133). Average speed: 2.59 s/mol.
# Processing CHEMBL191575 in molecule1.smi (11/133). Average speed: 0.89 s/mol.
# Processing CHEMBL209287 in molecule1.smi (15/133). Average speed: 0.71 s/mol.
# Processing CHEMBL370923 in molecule1.smi (12/133). Average speed: 0.69 s/mol.
# Processing CHEMBL358279 in molecule1.smi (16/133). Average speed: 0.71 s/mol.
# Processing CHEMBL194398 in molecule1.smi (13/133). Average speed: 0.69 s/mol.
# ...

# %% [markdown]
# ### New Drug -------------------------------------

# %%
try :
    df2 = pd.read_csv('data/corona_drug2_sars2.csv')
    df2_selected = df2[selection]
    df2_selected.to_csv('molecule2.smi',sep='\t',index=False,header=False)
except:
    pass

# %%
! cat molecule2.smi | wc -l
# Out:
# 195

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2023-01-12 22:30:42--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2023-01-12 22:30:42--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# ...

# %%
! bash padel.sh
# Out:
# Processing CHEMBL480 in molecule2.smi (1/195).
# Processing CHEMBL3545157 in molecule2.smi (3/195).
# Processing CHEMBL178459 in molecule2.smi (2/195).
# Processing CHEMBL297453 in molecule2.smi (4/195).
# Processing CHEMBL4303595 in molecule2.smi (5/195).
# Processing CHEMBL444186 in molecule2.smi (6/195).
# Processing CHEMBL55400 in molecule2.smi (7/195).
# Processing CHEMBL1886408 in molecule2.smi (8/195).
# Processing CHEMBL505670 in molecule2.smi (9/195). Average speed: 1.55 s/mol.
# Processing CHEMBL460499 in molecule2.smi (10/195). Average speed: 0.83 s/mol.
# Processing CHEMBL3665060 in molecule2.smi (12/195). Average speed: 0.68 s/mol.
# Processing CHEMBL1271993 in molecule2.smi (11/195). Average speed: 0.67 s/mol.
# Processing CHEMBL1096979 in molecule2.smi (13/195). Average speed: 0.45 s/mol.
# Processing CHEMBL164 in molecule2.smi (14/195). Average speed: 0.45 s/mol.
# Processing CHEMBL1422849 in molecule2.smi (15/195). Average speed: 0.39 s/mol.
# ...

# %% [markdown]
# ## New Drug ----------------------------------------

# %%
df3 = pd.read_csv('data/SARS_1.csv')
len(df3)
# Out:
# 214

# %%
df3_selected = df3[selection]

# %%
df3_selected
# Out:
#                                       canonical_smiles molecule_chembl_id
# 0    CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@@H...       CHEMBL194398
# 1    CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...       CHEMBL393608
# 2    CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...       CHEMBL238216
# 3    CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...       CHEMBL235873
# 4    CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...       CHEMBL397154
# ..                                                 ...                ...
# 209  CC(C)C[C@H](NC(=O)OC1(Cc2ccccc2)CCN(S(C)(=O)=O...      CHEMBL4208764
# 210  CCC1(OC(=O)N[C@@H](CC(C)C)C(=O)N[C@H](C=O)C[C@...      CHEMBL4212620
# 211  CCC1(OC(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C[C@@H]...      CHEMBL4216101
# 212  CCOC(=O)N1CCC(OC(=O)N[C@@H](CC(C)C)C(=O)N[C@H]...      CHEMBL4217568
# 213  CCOC(=O)N1CCC(OC(=O)N[C@@H](CC(C)C)C(=O)N[C@@H...      CHEMBL4204431
#
# [214 rows x 2 columns]

# %%
df3_selected.to_csv('molecule3.smi',sep='\t',header=False,index=False)

# %%
# try :
#     df3 = pd.read_csv('data/SARS_1.csv')
#     df3_selected = df3[selection]
#     df3_selected.to_csv('molecule3.smi',sep='\t',header=False,index=False)
# except :
#     pass

# %%
! bash padel.sh
# Out:
# Processing CHEMBL194398 in molecule3.smi (1/214).
# Processing CHEMBL393608 in molecule3.smi (2/214).
# Processing CHEMBL238216 in molecule3.smi (3/214).
# Processing CHEMBL235873 in molecule3.smi (4/214).
# Processing CHEMBL397154 in molecule3.smi (5/214).
# Processing CHEMBL238217 in molecule3.smi (6/214).
# Processing CHEMBL196635 in molecule3.smi (7/214).
# Processing CHEMBL492571 in molecule3.smi (8/214).
# Processing CHEMBL492771 in molecule3.smi (11/214). Average speed: 1.10 s/mol.
# Processing CHEMBL492771 in molecule3.smi (10/214). Average speed: 1.09 s/mol.
# Processing CHEMBL522710 in molecule3.smi (9/214). Average speed: 2.13 s/mol.
# Processing CHEMBL492772 in molecule3.smi (12/214). Average speed: 0.57 s/mol.
# Processing CHEMBL492768 in molecule3.smi (13/214). Average speed: 0.59 s/mol.
# Processing CHEMBL492770 in molecule3.smi (16/214). Average speed: 0.32 s/mol.
# Processing CHEMBL492769 in molecule3.smi (15/214). Average speed: 0.48 s/mol.
# ...
